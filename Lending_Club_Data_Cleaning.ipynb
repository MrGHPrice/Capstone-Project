# %% [markdown]
# ## Data cleaning.

# %%
df = pd.read_csv('~/Desktop/CSVs/LendingClubLoans.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (20,48,56,113,124,125,126,129,130,131,134,140,141,142) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.shape
# Out:
# (1344331, 146)

# %%
# Cleaning columns, changing strings to integers
df.describe()
# Out:
#         id  member_id     loan_amnt   funded_amnt  funded_amnt_inv  \
# count  0.0        0.0  1.344331e+06  1.344331e+06     1.344331e+06
# mean   NaN        NaN  1.462604e+04  1.461719e+04     1.458969e+04
# std    NaN        NaN  8.978526e+03  8.974955e+03     8.981656e+03
# min    NaN        NaN  5.000000e+02  5.000000e+02     0.000000e+00
# 25%    NaN        NaN  8.000000e+03  8.000000e+03     7.875000e+03
# 50%    NaN        NaN  1.200000e+04  1.200000e+04     1.200000e+04
# 75%    NaN        NaN  2.000000e+04  2.000000e+04     2.000000e+04
# max    NaN        NaN  4.000000e+04  4.000000e+04     4.000000e+04
#
#                term      int_rate   installment    annual_inc  url  \
# count  1.344331e+06  1.344331e+06  1.344331e+06  1.344327e+06  0.0
# mean   4.247021e+01  1.338206e-01  4.393933e+02  7.753987e+04  NaN
# std    1.064995e+01  4.841680e-02  2.659519e+02  1.293549e+05  NaN
# min    3.600000e+01  5.320000e-02  4.930000e+00  0.000000e+00  NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1344354 entries, 0 to 1344353
# Columns: 145 entries, id to settlement_term
# dtypes: float64(106), object(39)
# memory usage: 1.5+ GB

# %%
df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  \
# 0 NaN        NaN     5000.0       5000.0           4975.0  36.0    0.1065
# 1 NaN        NaN     2500.0       2500.0           2500.0  60.0    0.1527
# 2 NaN        NaN     2400.0       2400.0           2400.0  36.0    0.1596
# 3 NaN        NaN    10000.0      10000.0          10000.0  36.0    0.1349
# 4 NaN        NaN     3000.0       3000.0           3000.0  60.0    0.1269
#
#    installment grade sub_grade                 emp_title emp_length  \
# 0       162.87     B        B2                       NaN  10+ years
# 1        59.83     C        C4                     Ryder   < 1 year
# 2        84.33     C        C5                       NaN  10+ years
# 3       339.31     C        C1       AIR RESOURCES BOARD  10+ years
# 4        67.79     B        B5  University Medical Group     1 year
#
#   home_ownership  annual_inc verification_status   issue_d  loan_status  \
# ...

# %%
# dropping lines with no term details
df = df[~df.term.isnull()]

# %%
"""
Converting term and int_rate columns to floats.
"""
x = "36 months"
float(x.split(" ")[0])
# Out:
# 36.0

# %%
df['term'] = df.term.map(lambda x: float(x.split(" ")[1]))

# %%
y = "10.65%"
float(y.split("%")[0])/100
# Out:
# 0.1065

# %%
df['int_rate'] = df.int_rate.map(lambda x: float(x.split("%")[0])/100)

# %%
df['revol_util'] = df.revol_util.map(lambda x: float(x.split("%")[0])/100 if type(x) == str else x/100)

# %%
df.tail(20)
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 1344311 NaN        NaN    10500.0      10500.0          10500.0  36.0
# 1344312 NaN        NaN    35000.0      35000.0          35000.0  36.0
# 1344313 NaN        NaN    35000.0      35000.0          35000.0  60.0
# 1344314 NaN        NaN    25000.0      25000.0          25000.0  60.0
# 1344315 NaN        NaN    10000.0      10000.0          10000.0  60.0
# 1344316 NaN        NaN    15000.0      15000.0          15000.0  36.0
# 1344317 NaN        NaN    17950.0      17950.0          17950.0  60.0
# 1344318 NaN        NaN    30000.0      30000.0          30000.0  60.0
# 1344319 NaN        NaN    19000.0      19000.0          19000.0  60.0
# 1344320 NaN        NaN    18000.0      18000.0          18000.0  60.0
# 1344321 NaN        NaN    15000.0      15000.0          15000.0  60.0
# 1344322 NaN        NaN     3500.0       3500.0           3500.0  36.0
# ...

# %%
df.emp_length.unique()
# Out:
# array(['10+ years', '< 1 year', '1 year', '3 years', '8 years', '9 years',
#        '4 years', '5 years', '6 years', '2 years', '7 years', nan],
#       dtype=object)

# %%
# counting different sub_grades and loan_statuses to outline potential targets for prediction
df.sub_grade.value_counts()
# Out:
# C1    91077
# B5    87813
# B3    83701
# B4    82944
# C2    80427
# C4    78242
# C3    78067
# B1    75208
# B2    74920
# C5    74823
# A5    58051
# A4    48740
# D1    48443
# A1    45530
# D2    44712
# D3    39097
# A3    37031
# A2    35162
# D4    33109
# D5    27363
# E1    20343
# E2    18397
# E3    15746
# E4    13747
# E5    13500
# F1     8617
# F2     6338
# F3     5630
# F4     4467
# F5     3756
# G1     2857
# G2     2025
# G3     1652
# G4     1446
# G5     1350
# Name: sub_grade, dtype: int64

# %%
df.loan_status.value_counts()
# Out:
# Current                                                636691
# Fully Paid                                             546870
# Charged Off                                            130391
# Late (31-120 days)                                      15329
# In Grace Period                                          8758
# Late (16-30 days)                                        3522
# Does not meet the credit policy. Status:Fully Paid       1988
# Does not meet the credit policy. Status:Charged Off       761
# Default                                                    21
# Name: loan_status, dtype: int64
